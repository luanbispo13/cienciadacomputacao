# %% [markdown]
# Tuplas - Dia 14.03
#
# [acesse o livro](https://edisciplinas.usp.br/pluginfile.php/6585696/mod_resource/content/1/Eric%20Matthes%20-%20Curso%20Intensivo%20de%20Python-Novatec%20%282016%29.pdf)
#
# As listas funcionam bem para armazenar conjuntos de itens que podem
# mudar durante a vida de um programa. A capacidade de modificar listas
# é particularmente importante quando trabalhamos com uma lista de
# usuários em um site ou com uma lista de personagens em um jogo. No
# entanto, às vezes, você vai querer criar uma lista de itens que não poderá
# mudar. As tuplas permitir fazer exatamente isso. Python refere-se a
# valores que não podem mudar como imutáveis, e uma lista imutável é
# chamada de tupla.
#
# Definindo uma Tupla
#
# Uma tupla se parece exatamente com uma lista, exceto por usar
# parênteses no lugar de colchetes. Depois de definir uma tupla, podemos
# acessar elementos individuais usando o índice de cada item, como
# faríamos com uma lista.

# %%
lista = [1, 2, 3, 4]
lista_vazia = []
listas = lista + lista_vazia # concatenação de listas, resultado uma lista.
print(listas)
type(listas)
listas.append("Luan") #em listas o método append() adiciona um elemento na lista.
print(listas)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4, 'Luan']

# %%
tupla = (1, 2, 3, 4)
tupla_vazia = ()
tuplas = tupla + tupla_vazia # concatenação de tuplas, resultado uma tupla.
print(tuplas)
type(tuplas)
tuplas.append("Luan") #em tuplas o método append() não é suportado.
tuplas.clear()
print(tuplas)

# %%
# não é possível somar lista e dupla

tupla = (1, 2, 3, 4)
lista = [1, 2, 3, 4]
soma = tupla + lista
print(soma)

# %%
tupla = (1,)

# %%
# uma tupla com um único elemento, tem que ter uma vírgula após o elemento.

tupla_1 = (1,) # se não colocar vírgula, a tupla_1 será uma variável do tipo INT
print(tupla_1)
type(tupla_1)
tupla_2 = (1) # a tupla 2 recebe uma variável do tipo INT
print(tupla_2)
type(tupla_2)
# Out:
# (1,)
# 1
# int

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Questão Desafio (1.0 ponto) reescrever a tupla com as modificações do cardápio.

buffet = ("carne", "frango", "batata frita", "purê de batata", "salada")
nova_comida = ()
buffet_completo = buffet + nova_comida
print("o buffet completo é composto pelos pratos: ".format(buffet_completo))
for comida in buffet_completo:
  print(comida)
# Out:
# o buffet completo é composto pelos pratos:
# carne
# frango
# batata frita
# purê de batata
# salada

# %%
# Questão Desafio Respondida

buffet = ("carne", "frango", "batata frita", "purê de batata", "frango grelhado")
print("Pratos oferecidos pelo restaurante:")
for prato in buffet:
    print(prato)

buffet = ("carne", "frango", "lasanha", "salada mista", "frango grelhado")

print("\nCardápio revisado do restaurante:")
for prato in buffet:
    print(prato)
# Out:
# Pratos oferecidos pelo restaurante:
# carne
# frango
# batata frita
# purê de batata
# frango grelhado
#
# Cardápio revisado do restaurante:
# carne
# frango
# lasanha
# salada mista
# frango grelhado

# %%
buffet = ("carne", "frango", "batata frita", "purê de batata", "salada")
nova_comida = ("salada", "lasanha")
buffet_completo = buffet[0:2] + nova_comida + buffet[2:]
print("O buffet completo é composto pelos pratos:")
for comida in buffet_completo:
    print(comida)
# Out:
# O buffet completo é composto pelos pratos:
# carne
# frango
# salada
# lasanha
# batata frita
# purê de batata
# salada
