# %% [markdown]
# Estrutura de Dados - Lista - 07.03 ⏰

# %%
"amor" in "sp"
# Out:
# False

# %%
# Listas são cadeias de valores, isto é, armazenam mais de um valor. São estruturas ordenadas, mutáveis e heterogêneas.

# %%
lista1 = [15, 10, 23, 42, 56]
# print(lista1) pode executar somente lista 1.
lista1
# Out:
# [15, 10, 23, 42, 56]

# %%
# Listas vazias podem ser criadas usando-se uma das duas sintaxes a seguir: x = [] e x = list()
lista2 = []
lista2
# Out:
# []

# %%
lista1 + lista2 # concatenação de lista.
# Out:
# [15, 10, 23, 42, 56]

# %%
lista1[3]
# Out:
# 42

# %%
L = [1, 4.5, "abc", 3 + 4j, [1, 2, 3, 4]]
len(L) # apresenta o cumprimento de uma lista.
# Out:
# 5

# %%
# Para a adição de novos valores pode-se usar o método append(valor) ou o operador "+" que no caso das listas executa concatenação.
A = [1, 2, 3]
B = [4, 5, 6]
# A + B concatenação de lista ou soma
C = A+B
C += [7] # equivale a C = C + [7]
C.append("abc")
C
# Out:
# [1, 2, 3, 4, 5, 6, 7, 'abc']

# %%
# DICA: Índices negativos, a partir do -1, percorrem a lista de trás para frente.
C[-8]
# Out:
# 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# O comando dir(list) retorna os atributos e métodos das listas.
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
# append() adiciona elementos no final da lista:

# %%
# clear() esvazia a lista:
C.clear() # a lista C foi criada acima.
C
# Out:
# []

# %%
# count() retorna quantas ocorrências há do argumento passado:
números = [1, 2, 3, 3, 3, 3, 4]
números.count(3)
# Out:
# 4

# %%
# index() retorna o índice da primeira ocorrência do argumento passado:
números.index(3)
# Out:
# 2

# %%
# insert() insere na posição especificada um elemento:
números.insert(0, "luan")
números
# Out:
# ['luan', 1, 2, 3, 3, 3, 3, 4]

# %%
# pop() remove e retorna o elemento da posição especificada:
números.pop(3)
# Out:
# 3

# %%
# remove() remove o elemento especificado:
números.remove()

# %%
# reverse() inverte a ordem dos elementos:
números.reverse()

# %%
# sort() ordena:
números.sort()
